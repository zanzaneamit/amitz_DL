# %% [markdown]
# Q1. Write a Python program to get the string from the given string where
# all the occurrence of its first char has been changed to '$,' except first
# char itself?
#
#     Sample String: 'prospect'
#     Expected Result : 'pros$ect'

# %%
s=input()
s1=s[0] + s.replace(s[0],'$')[1:]
print(s1)
# Out:
# amitasz
# amit$sz

# %% [markdown]
# Q2. Write a Python program to get the single string from the two given
# strings, and separated by the space and swap the first two characters of
# each string?
#
#     Sample String : 'abc', 'xyz'.
#     Expected Result: 'xyc abz'

# %%
[s1,s2] = input().split()
s1_temp = s1[0:2]
s1 = s2[0:2] + s1[2:]
s2 = s1_temp + s2[2:]
print(s1 + ' ' + s2)
# Out:
# abc xyz
# xyc abz

# %% [markdown]
# Q3. Write the Python program to add 'ing' at the end of the given string
# (length of the string should be at least 3). If given string already ends
# with 'ing,' then add 'ly' instead. If string length of the given string is less
# than 3, leave it unchanged?
#
#
#     Sample string: ' abc '
#     Expected result: ' abcing '
#     Sample string: ' string '
#     Expected result: ' stringly '

# %%
s=input()
if len(s) >= 3:
  if s[-3:] == 'ing':
    s = s + 'ly'
  else:
    s = s + 'ing'

print(s)
# Out:
# ab
# ab
# ab

# %% [markdown]
# Q4. Write the Python program to find the first appearance of the
# substring 'not' and 'poor' from the given string, if 'not' follows the 'poor',
# replace the whole 'not'...' poor' substring with 'good'.Return the resulting
# string.
#
#     Sample string: 'The lyrics are not that poor!'
#     'The lyrics are poor!'
#     Expected Result: 'The lyrics are good!'
#     'The lyrics are poor!'

# %%
import re
s=input()
not_start = s.find('not')
if not_start >= 0:
  poor_pos = s.find('poor',not_start)
  if poor_pos >= 0:
    sub = s[not_start:poor_pos+4]
    s=s.replace(sub,'poor',1)

print(s)
# Out:
# The lyrics are not that poor!
# The lyrics are poor!

# %% [markdown]
# Q5. Write the Python program to remove the characters which have odd
# index values of a given string.

# %%
s=input()
s=s[::2]
print(s)
# Out:
# The lyrics are not that poor
# Telrc r o htpo

# %% [markdown]
# Q6. Write the python program to print the following floating numbers up
# to 2 decimal places?

# %%
f1=float(input())
print('%.2f'%f1)
# Out:
# 1234.5678
# 1234.57

# %% [markdown]
# Q7. Write the Python program to format a number with a percentage?

# %%
i1=int(input())
print('{:.2%}'.format(i1))
# Out:
# 123
# 12300.00%

# %% [markdown]
# Q8. Write the Python program to count occurrences of a substring in a
# String?

# %%
s=input('Input string')
sub=input('Input substring to search')

print(s.count(sub))
# Out:
# Input stringzanzane
# Input substring to searchzan
# 2

# %% [markdown]
# Q9. Write the Python program to count repeated characters in a string.
#
#     Sample string: ' thequickbrownjumpsoverthelazydog '
#
#     Expected output:
#     o 3
#     e 3
#     u 2
#     h 2
#     r 2
#     t 2

# %%
s=input('Input string')

d=dict()
for i in s:
  if i in d:
    d[i] = d[i] + 1
  else:
    d[i] = 1

for k,v in d.items():
  print(k + ' ' + str(v))

#sorted(d.items(),key= lambda kv: kv[1],reverse=True)
# Out:
# Input stringthequickbrownjumpsoverthelazydog
# t 2
# h 2
# e 3
# q 1
# u 2
# i 1
# c 1
# k 1
# b 1
# r 2
# o 3
# w 1
# n 1
# j 1
# m 1
# p 1
# s 1
# v 1
# l 1
# a 1
# z 1
# y 1
# d 1
# g 1

# %% [markdown]
# Q10. Write the Python program to print the square and cube symbol in
# the area of a rectangle and volume of a cylinder?
#
#     Sample outputThe area of the rectangle is 1256.66cm2
#     The volume of the cylinder is 1254.725cm3

# %%
n=int(input('2 for rectangle or 3 for cylinder'))
a=float(input('area'))
if n==2:
  measure = 'area'
  typ = 'rectangle'
if n==3:
  measure = 'volume'
  typ = 'cylinder'


print('The %s of the %s is %f cm%d' %(measure,typ,a,n))
# Out:
# 2 for rectangle or 3 for cylinder2
# area1234.4567
# The area of the rectangle is 1234.456700 cm2

# %% [markdown]
# Q11. Write the Python program to check if a string contains all letters of
# the alphabet?

# %%
import re
s=input()
print(all(re.search(regex, s, flags=re.IGNORECASE) for regex in list(map(chr, range(97, 123)))))
# Out:
# ABCDEFGHIJKLMNOPQRSTUVWXY
# False

# %% [markdown]
# Q12. Write the Python program to find the second most repeated word
# in a given string?

# %%
s=input('Input string')

d=dict()

for i in s:
  if i in d:
    d[i] = d[i] + 1
  else:
    d[i] = 1

d_sorted=sorted(d.items(),key= lambda kv: kv[1],reverse=True)
#print(d_sorted)
most_repeat = d_sorted[0][1]
for (k,v) in d_sorted:
  print(k + ' ' + str(v))
  if most_repeat > v:
    break
# Out:
# Input stringstringthequickbrownjumpsoverthelazydog
# t 3
# r 3
# e 3
# o 3
# s 2
# s

# %% [markdown]
# Q13. Write the Python program to find the minimum window in the given
# string, which will contains all the characters of another given
# strings?
#
#     Example 1
#     Input : string1 = " PRWSOERIUSFK "
#     string2 = " OSU "
#     Output: Minimum window is "OERIUS"

# %%
import re
s=input('Input string1')
srch = input('string2')

l=len(s)

matched=dict()
for i in range(l):
  for j in range(l):
    #print(s[i:j])
    if (all(re.search(regex, s[i:j], flags=re.IGNORECASE) for regex in list(srch))):
      matched[j-i] = s[i:j]

smallest = 0
for k,v in matched.items():
  if smallest == 0:
    smallest = k
  else:
    if smallest > k:
      smallest = k
print(matched[smallest])
# Out:
# Input string1PRWSOERIUSFK
# string2OSU
# OERIUS

# %% [markdown]
# Q14. Write the Python program to count number of substrings from a
# given string of lowercase alphabets with exactly k distinct (given)
# characters?
#
#     Input a string (lowercase alphabets): wolf
#     Input k: 4
#     Number of substrings with exactly 4 distinct characters: 1

# %%
from itertools import combinations
s=input('Input a string (lowercase alphabets):')
n=int(input('Input k:'))
comb = combinations(s,n)
comb = [i for i in comb]
print('Number of substrings with exactly %d distinct characters: %d' %(n,len(comb)))
# Out:
# Input a string (lowercase alphabets):wolf
# Input k:3
# Number of substrings with exactly 3 distinct characters: 4

# %% [markdown]
# Q15. Write the Python program to count number of substrings with same
# first and last characters of the given string?
#
#     Input a string: abcd
#     4

# %%
s=input('Input a string: ')
s_len = len(s)
fixed_char=2
print('%d' %(pow(2,s_len-fixed_char)))
# Out:
# Input a string: abcde
# 8

# %% [markdown]
# ## Great Job!
